# %% [raw]
# ---
# title: "Using LLMs to Plan Multi-Step Projects"
# author: "Alex Rosen"
# date: "December 18, 2025"
# categories:
# - llms
# - planning
# - workflows
# ---

# %% [raw]
# <h1 style="color: #96174e">Using LLMs to Plan Multi-Step Projects</h1>
#
# <p>In this post, I examined how an LLM can be used to plan a multi-step project. Complex projects often feel overwhelming because it is difficult to see all the steps at once.</p>
#
# <p>Rather than asking the model to complete any work directly, I used it as a planning assistant to break a large task into manageable stages.</p>
#
# <h4 style="color:#0707ff">The Graphic</h4>
#
# <p>
# <img src="image.png" alt="LLM breaking a project into structured steps" width="60%">
# </p>
#
#
# <h4 style="color:#0707ff">Project Goal</h4>
#
# <p style="background-color: #f8f8f8; padding: 10px; border-radius: 8px;">
# Create a semester-long blog series exploring practical uses of large language models.
# </p>
#
# <h4 style="color:#0707ff">Prompt</h4>
#
# <div style="background-color: #f8f8f8; padding: 10px; border-radius: 8px;">
# <blockquote>
# Break this project into clear phases with a short description of what happens in each phase.
# </blockquote>
# </div>
#
# <h4 style="color:#0707ff">Response</h4>
#
# <div style="background-color: #f0f8ff; padding: 10px; border-radius: 8px;">
# <blockquote>
# Phase 1: Define the scope and audience for the blog series.
# Phase 2: Identify and test specific LLM use cases.
# Phase 3: Draft and revise individual blog posts.
# Phase 4: Create visuals and supporting examples.
# Phase 5: Publish posts and reflect on outcomes.
# </blockquote>
# </div>
#
# <p>The response helped clarify the structure of the project without dictating content. Seeing the process laid out made the task feel more achievable.</p>
#
# <h1 style="color: #96174e">Reflection</h1>
#
# <p>This experiment showed that LLMs can be useful tools for organization and planning. Instead of jumping straight into execution, I could step back and think strategically.</p>
#
# <p>For blogging and coursework, this approach helps reduce cognitive overload. The model support
